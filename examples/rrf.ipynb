# %% [markdown]
# # Imports

# %%
import pandas as pd
from think_reason_learn.rrf import RRF
from think_reason_learn.core.llms import GoogleChoice, OpenAIChoice

# %% [markdown]
# # Log level

# %%
import logging
import sys

logging.basicConfig(
    level=logging.WARNING,  # You might want debug or info
    stream=sys.stdout,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    force=True,
)

logging.getLogger("google_genai.models").setLevel(logging.ERROR)
logging.getLogger("google_genai.models").propagate = False

# %% [markdown]
# # Data

# %%
person1 = """\
A is a 30-year-old woman living in San Francisco. She studied computer science at \
Stanford and worked for six years as a senior engineer at Google on \
large-scale distributed systems. She recently left to start an AI-powered healthcare \
analytics company and has already raised a $2M seed round from \
well-known Bay Area investors.
"""

person2 = """\
B is a 25-year-old man based in New York City. He graduated with a degree in \
marketing from NYU and has been working as a marketing manager at Apple for \
the past three years. He is trying to launch a social media app. Before apple, \
he was a product manager at Facebook.
"""

person3 = """\
C is stay in Los Angeles. He is a practicing medical doctor at UCLA \
and is working on a remote patient monitoring platform. He has limited \
technical knowledge and no startup experience, relying heavily on contractors \
for development. He is also a big fan of the Lakers.
"""

person4 = """\
D is a 40-year-old man living in Chicago. He studied law at the University of \
Chicago and has built a career as a corporate lawyer specializing in \
mergers and acquisitions. He is exploring a legal-tech startup idea but is \
still working full-time at his law firm and has no technical or entrepreneurial \
background.
"""

person5 = """\
E is a 28-year-old woman in San Francisco. She studied computer engineering at \
UC Berkeley and worked as a software engineer at a YC-backed fintech startup \
that scaled rapidly. She is now building her own fintech product for underbanked \
communities and has early traction with pilot customers in Latin America.
"""

person6 = """\
F is a 32-year-old man based in New York City. He earned his MBA from Columbia \
Business School after working in marketing roles at Apple and Spotify. He is \
now working on a consumer subscription box startup, but customer acquisition costs \
have been high, and he is struggling to attract investors without stronger traction.
"""

person7 = """\
G is a 27-year-old woman living in Austin, Texas. She studied industrial engineering \
at MIT and later worked as a product manager at Amazon, focusing on supply chain \
logistics. She has teamed up with two cofounders from her professional network to \
launch a logistics automation startup and recently joined a prominent accelerator.
"""

person8 = """\
H has worked in 7 companies, in 3 different industries. He is currently a product \
manager at a startup in the fintech industry. He is looking to launch a new \
product in the edutech industry.
"""

# %%
X = pd.DataFrame(
    {
        "data": [
            person1,
            person2,
            person3,
            person4,
            person5,
            person6,
            person7,
            person8,
        ]
    }
)
y = ["YES", "NO", "NO", "YES", "NO", "NO", "YES", "NO"]

# %% [markdown]
# # RRF

# %%
rrf = RRF(
    qgen_llmc=[
        GoogleChoice(model="gemini-2.0-flash-lite"),
        OpenAIChoice(model="gpt-4.1-nano"),
    ],
    name="test_rrf",
    answer_similarity_func="hamming",
    max_samples_as_context=5,
    max_generated_questions=30,
)

# %%
instructions_tem = await rrf.set_tasks(
    task_description="The task is to classify the founders as successful or not"
)
print(instructions_tem)
# Out:
# You are tasked with generating <number_of_questions> YES/NO questions designed to distinguish between successful and unsuccessful founders. Your goal is to create questions that would help classify a founder into one of these two categories.
#
# Consider factors that differentiate successful founders from those who are not successful. Think about various aspects of a founder's journey, including their background, actions, strategies, and the outcomes they achieved.
#
# Each subsequent question should build upon the "cumulative memory" of insights gathered from the questions generated previously. "Cumulative memory" is a high-level summary of the key themes, patterns, and important aspects that previous questions have explored. When generating new questions, refer to and expand upon the cumulative memory to ensure your questions cover diverse yet relevant aspects of founder success while avoiding repetition. This will help to identify valuable question directions and guide future question generation.
#
# In summary, generate YES/NO questions that are discriminative for the task, making sure that each question builds upon the "cumulative memory" of previous questions.

# %%
rrf = await rrf.fit(X, y, reset=True)

# %%
rrf.get_questions()
# Out:
#                                               question embedding exclusion  \
# 000  Did the founder have prior experience in the i...      None      None
# 001  Did the founder have a co-founder or a strong ...      None      None
# 002  Did the founder have a clear understanding of ...      None      None
# 003  Did the founder secure any funding or investme...      None      None
# 004  Did the founder build a minimum viable product...      None      None
# 005  Did the founder demonstrate adaptability by pi...      None      None
# 006  Did the founder possess a strong network of me...      None      None
# 007  Did the founder exhibit a track record of succ...      None      None
# 008  Did the founder possess the technical skills r...      None      None
# 009    Did the founder build a strong company culture?      None      None
# 010  Did the founder effectively manage their perso...      None      None
# 011  Did the founder prioritize customer acquisitio...      None      None
# 012  Did the founder have a defined go-to-market st...      None      None
# 013  Did the founder seek out and leverage feedback...      None      None
# 014  Did the founder demonstrate resilience in the ...      None      None
# 015  Did the founder have prior experience in the t...      None      None
# 016  Did the founder have a co-founder with complem...      None      None
# 017  Did the founder conduct thorough market resear...      None      None
# 018  Did the founder secure funding (e.g., seed rou...      None      None
# 019  Did the founder launch a Minimum Viable Produc...      None      None
# 020  Does the founder have a clear understanding of...      None      None
# 021  Has the founder demonstrated the ability to ad...      None      None
# 022  Does the founder have a robust sales and marke...      None      None
# 023  Has the founder successfully acquired paying c...      None      None
# 024  Does the founder have a strong network of ment...      None      None
# 025  Does the founder effectively manage the compan...      None      None
# 026  Has the founder demonstrated resilience in the...      None      None
# 027  Does the founder possess strong communication ...      None      None
# 028  Does the founder have a clear plan for scaling...      None      None
# 029  Has the founder built a strong and motivated t...      None      None
#
#     precision    recall  f1_score accuracy
# 000       0.4  0.666667       0.5      0.5
# 001       1.0  0.333333       0.5     0.75
# 002       0.0       0.0       0.0      0.5
# 003       1.0  0.333333       0.5     0.75
# 004       0.0       0.0       0.0      0.5
# 005       0.0       0.0       0.0    0.625
# 006       0.0       0.0       0.0    0.625
# 007       0.5  0.666667  0.571429    0.625
# 008  0.666667  0.666667  0.666667     0.75
# 009       0.0       0.0       0.0    0.625
# 010       0.0       0.0       0.0    0.625
# 011       0.0       0.0       0.0    0.625
# 012       0.0       0.0       0.0    0.625
# 013       0.0       0.0       0.0      0.5
# 014       0.0       0.0       0.0    0.625
# 015  0.333333  0.333333  0.333333      0.5
# 016       1.0  0.333333       0.5     0.75
# 017       0.0       0.0       0.0    0.625
# 018       1.0  0.333333       0.5     0.75
# 019       0.0       0.0       0.0    0.625
# 020       0.0       0.0       0.0      0.5
# 021       0.0       0.0       0.0    0.625
# 022       0.0       0.0       0.0    0.625
# 023       0.0       0.0       0.0      0.5
# 024       0.0       0.0       0.0    0.625
# 025       0.0       0.0       0.0    0.625
# 026       0.0       0.0       0.0    0.625
# 027       0.0       0.0       0.0    0.625
# 028       0.0       0.0       0.0    0.625
# 029       0.0       0.0       0.0    0.625

# %%
rrf.get_answers()
# Out:
#    000  001  002  003  004 005 006  007  008 009  ...  020 021 022  023 024  \
# 0  YES   NO   NO  YES   NO  NO  NO  YES  YES  NO  ...   NO  NO  NO   NO  NO
# 1  YES   NO   NO   NO   NO  NO  NO  YES   NO  NO  ...   NO  NO  NO   NO  NO
# 2   NO   NO   NO   NO   NO  NO  NO   NO   NO  NO  ...   NO  NO  NO   NO  NO
# 3   NO   NO   NO   NO   NO  NO  NO   NO   NO  NO  ...   NO  NO  NO   NO  NO
# 4  YES   NO  YES   NO  YES  NO  NO  YES  YES  NO  ...  YES  NO  NO  YES  NO
# 5  YES   NO   NO   NO   NO  NO  NO   NO   NO  NO  ...   NO  NO  NO   NO  NO
# 6  YES  YES   NO   NO   NO  NO  NO  YES  YES  NO  ...   NO  NO  NO   NO  NO
# 7   NO   NO   NO   NO   NO  NO  NO   NO   NO  NO  ...   NO  NO  NO   NO  NO
#
#   025 026 027 028 029
# 0  NO  NO  NO  NO  NO
# 1  NO  NO  NO  NO  NO
# 2  NO  NO  NO  NO  NO
# 3  NO  NO  NO  NO  NO
# 4  NO  NO  NO  NO  NO
# 5  NO  NO  NO  NO  NO
# 6  NO  NO  NO  NO  NO
# 7  NO  NO  NO  NO  NO
#
# [8 rows x 30 columns]

# %%
# rrf.filter_questions_on_pred_similarity(threshold=None)
# await rrf.filter_questions_on_semantics(
#     threshold=None,
#     emb_model="hashed_bag_of_words",
# )
# rrf.get_questions()

# %%
preds = []
async for pred in rrf.predict(X):
    preds.append(pred)  # type: ignore
    print(pred)
# Out:
# (1, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=1, value=174, is_min_estimate=False, callers={'RRF._answer_single_question': 1})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=2, value=355, is_min_estimate=False, callers={'RRF._answer_single_question': 2})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=3, value=518, is_min_estimate=False, callers={'RRF._answer_single_question': 3})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=4, value=692, is_min_estimate=False, callers={'RRF._answer_single_question': 4})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=5, value=869, is_min_estimate=False, callers={'RRF._answer_single_question': 5})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=6, value=1045, is_min_estimate=False, callers={'RRF._answer_single_question': 6})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=7, value=1221, is_min_estimate=False, callers={'RRF._answer_single_question': 7})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=8, value=1375, is_min_estimate=False, callers={'RRF._answer_single_question': 8})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=9, value=1551, is_min_estimate=False, callers={'RRF._answer_single_question': 9})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=10, value=1716, is_min_estimate=False, callers={'RRF._answer_single_question': 10})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=11, value=1899, is_min_estimate=False, callers={'RRF._answer_single_question': 11})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=12, value=2075, is_min_estimate=False, callers={'RRF._answer_single_question': 12})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=13, value=2254, is_min_estimate=False, callers={'RRF._answer_single_question': 13})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=14, value=2432, is_min_estimate=False, callers={'RRF._answer_single_question': 14})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '001', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=15, value=2610, is_min_estimate=False, callers={'RRF._answer_single_question': 15})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=16, value=2782, is_min_estimate=False, callers={'RRF._answer_single_question': 16})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=17, value=2938, is_min_estimate=False, callers={'RRF._answer_single_question': 17})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=18, value=3099, is_min_estimate=False, callers={'RRF._answer_single_question': 18})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=19, value=3278, is_min_estimate=False, callers={'RRF._answer_single_question': 19})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '002', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=20, value=3450, is_min_estimate=False, callers={'RRF._answer_single_question': 20})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=21, value=3625, is_min_estimate=False, callers={'RRF._answer_single_question': 21})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=22, value=3799, is_min_estimate=False, callers={'RRF._answer_single_question': 22})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=23, value=3973, is_min_estimate=False, callers={'RRF._answer_single_question': 23})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=24, value=4125, is_min_estimate=False, callers={'RRF._answer_single_question': 24})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=25, value=4285, is_min_estimate=False, callers={'RRF._answer_single_question': 25})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=26, value=4456, is_min_estimate=False, callers={'RRF._answer_single_question': 26})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '003', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=27, value=4634, is_min_estimate=False, callers={'RRF._answer_single_question': 27})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=28, value=4805, is_min_estimate=False, callers={'RRF._answer_single_question': 28})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=29, value=4979, is_min_estimate=False, callers={'RRF._answer_single_question': 29})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=30, value=5152, is_min_estimate=False, callers={'RRF._answer_single_question': 30})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=31, value=5325, is_min_estimate=False, callers={'RRF._answer_single_question': 31})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=32, value=5476, is_min_estimate=False, callers={'RRF._answer_single_question': 32})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=33, value=5641, is_min_estimate=False, callers={'RRF._answer_single_question': 33})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=34, value=5817, is_min_estimate=False, callers={'RRF._answer_single_question': 34})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=35, value=6000, is_min_estimate=False, callers={'RRF._answer_single_question': 35})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=36, value=6176, is_min_estimate=False, callers={'RRF._answer_single_question': 36})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=37, value=6355, is_min_estimate=False, callers={'RRF._answer_single_question': 37})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=38, value=6533, is_min_estimate=False, callers={'RRF._answer_single_question': 38})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=39, value=6711, is_min_estimate=False, callers={'RRF._answer_single_question': 39})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=40, value=6867, is_min_estimate=False, callers={'RRF._answer_single_question': 40})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=41, value=7034, is_min_estimate=False, callers={'RRF._answer_single_question': 41})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=42, value=7212, is_min_estimate=False, callers={'RRF._answer_single_question': 42})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=43, value=7397, is_min_estimate=False, callers={'RRF._answer_single_question': 43})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=44, value=7578, is_min_estimate=False, callers={'RRF._answer_single_question': 44})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=45, value=7756, is_min_estimate=False, callers={'RRF._answer_single_question': 45})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=46, value=7936, is_min_estimate=False, callers={'RRF._answer_single_question': 46})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=47, value=8116, is_min_estimate=False, callers={'RRF._answer_single_question': 47})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=48, value=8274, is_min_estimate=False, callers={'RRF._answer_single_question': 48})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=49, value=8435, is_min_estimate=False, callers={'RRF._answer_single_question': 49})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=50, value=8607, is_min_estimate=False, callers={'RRF._answer_single_question': 50})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=51, value=8786, is_min_estimate=False, callers={'RRF._answer_single_question': 51})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=52, value=8961, is_min_estimate=False, callers={'RRF._answer_single_question': 52})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=53, value=9133, is_min_estimate=False, callers={'RRF._answer_single_question': 53})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=54, value=9307, is_min_estimate=False, callers={'RRF._answer_single_question': 54})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=55, value=9481, is_min_estimate=False, callers={'RRF._answer_single_question': 55})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=56, value=9633, is_min_estimate=False, callers={'RRF._answer_single_question': 56})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=57, value=9796, is_min_estimate=False, callers={'RRF._answer_single_question': 57})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '007', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=58, value=9970, is_min_estimate=False, callers={'RRF._answer_single_question': 58})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '007', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=59, value=10151, is_min_estimate=False, callers={'RRF._answer_single_question': 59})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=60, value=10328, is_min_estimate=False, callers={'RRF._answer_single_question': 60})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=61, value=10502, is_min_estimate=False, callers={'RRF._answer_single_question': 61})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=62, value=10678, is_min_estimate=False, callers={'RRF._answer_single_question': 62})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '007', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=63, value=10854, is_min_estimate=False, callers={'RRF._answer_single_question': 63})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=64, value=11008, is_min_estimate=False, callers={'RRF._answer_single_question': 64})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=65, value=11180, is_min_estimate=False, callers={'RRF._answer_single_question': 65})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=66, value=11363, is_min_estimate=False, callers={'RRF._answer_single_question': 66})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '008', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=67, value=11553, is_min_estimate=False, callers={'RRF._answer_single_question': 67})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=68, value=11739, is_min_estimate=False, callers={'RRF._answer_single_question': 68})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '008', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=69, value=11922, is_min_estimate=False, callers={'RRF._answer_single_question': 69})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=70, value=12107, is_min_estimate=False, callers={'RRF._answer_single_question': 70})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '008', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=71, value=12292, is_min_estimate=False, callers={'RRF._answer_single_question': 71})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=72, value=12455, is_min_estimate=False, callers={'RRF._answer_single_question': 72})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=73, value=12613, is_min_estimate=False, callers={'RRF._answer_single_question': 73})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=74, value=12782, is_min_estimate=False, callers={'RRF._answer_single_question': 74})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=75, value=12958, is_min_estimate=False, callers={'RRF._answer_single_question': 75})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=76, value=13130, is_min_estimate=False, callers={'RRF._answer_single_question': 76})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=77, value=13299, is_min_estimate=False, callers={'RRF._answer_single_question': 77})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=78, value=13470, is_min_estimate=False, callers={'RRF._answer_single_question': 78})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=79, value=13641, is_min_estimate=False, callers={'RRF._answer_single_question': 79})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=80, value=13790, is_min_estimate=False, callers={'RRF._answer_single_question': 80})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=81, value=13951, is_min_estimate=False, callers={'RRF._answer_single_question': 81})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=82, value=14123, is_min_estimate=False, callers={'RRF._answer_single_question': 82})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=83, value=14302, is_min_estimate=False, callers={'RRF._answer_single_question': 83})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=84, value=14477, is_min_estimate=False, callers={'RRF._answer_single_question': 84})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=85, value=14649, is_min_estimate=False, callers={'RRF._answer_single_question': 85})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=86, value=14823, is_min_estimate=False, callers={'RRF._answer_single_question': 86})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=87, value=14997, is_min_estimate=False, callers={'RRF._answer_single_question': 87})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=88, value=15149, is_min_estimate=False, callers={'RRF._answer_single_question': 88})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=89, value=15307, is_min_estimate=False, callers={'RRF._answer_single_question': 89})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=90, value=15476, is_min_estimate=False, callers={'RRF._answer_single_question': 90})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=91, value=15652, is_min_estimate=False, callers={'RRF._answer_single_question': 91})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=92, value=15824, is_min_estimate=False, callers={'RRF._answer_single_question': 92})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=93, value=15995, is_min_estimate=False, callers={'RRF._answer_single_question': 93})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=94, value=16166, is_min_estimate=False, callers={'RRF._answer_single_question': 94})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=95, value=16335, is_min_estimate=False, callers={'RRF._answer_single_question': 95})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=96, value=16484, is_min_estimate=False, callers={'RRF._answer_single_question': 96})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=97, value=16646, is_min_estimate=False, callers={'RRF._answer_single_question': 97})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=98, value=16819, is_min_estimate=False, callers={'RRF._answer_single_question': 98})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=99, value=16995, is_min_estimate=False, callers={'RRF._answer_single_question': 99})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=100, value=17175, is_min_estimate=False, callers={'RRF._answer_single_question': 100})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=101, value=17350, is_min_estimate=False, callers={'RRF._answer_single_question': 101})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=102, value=17523, is_min_estimate=False, callers={'RRF._answer_single_question': 102})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=103, value=17698, is_min_estimate=False, callers={'RRF._answer_single_question': 103})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=104, value=17851, is_min_estimate=False, callers={'RRF._answer_single_question': 104})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=105, value=18025, is_min_estimate=False, callers={'RRF._answer_single_question': 105})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=106, value=18188, is_min_estimate=False, callers={'RRF._answer_single_question': 106})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=107, value=18365, is_min_estimate=False, callers={'RRF._answer_single_question': 107})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=108, value=18546, is_min_estimate=False, callers={'RRF._answer_single_question': 108})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=109, value=18722, is_min_estimate=False, callers={'RRF._answer_single_question': 109})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '013', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=110, value=18896, is_min_estimate=False, callers={'RRF._answer_single_question': 110})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=111, value=19072, is_min_estimate=False, callers={'RRF._answer_single_question': 111})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=112, value=19226, is_min_estimate=False, callers={'RRF._answer_single_question': 112})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=113, value=19399, is_min_estimate=False, callers={'RRF._answer_single_question': 113})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=114, value=19575, is_min_estimate=False, callers={'RRF._answer_single_question': 114})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=115, value=19737, is_min_estimate=False, callers={'RRF._answer_single_question': 115})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=116, value=19917, is_min_estimate=False, callers={'RRF._answer_single_question': 116})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=117, value=20092, is_min_estimate=False, callers={'RRF._answer_single_question': 117})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=118, value=20265, is_min_estimate=False, callers={'RRF._answer_single_question': 118})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=119, value=20440, is_min_estimate=False, callers={'RRF._answer_single_question': 119})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=120, value=20593, is_min_estimate=False, callers={'RRF._answer_single_question': 120})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=121, value=20768, is_min_estimate=False, callers={'RRF._answer_single_question': 121})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=122, value=20932, is_min_estimate=False, callers={'RRF._answer_single_question': 122})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=123, value=21110, is_min_estimate=False, callers={'RRF._answer_single_question': 123})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=124, value=21292, is_min_estimate=False, callers={'RRF._answer_single_question': 124})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=125, value=21467, is_min_estimate=False, callers={'RRF._answer_single_question': 125})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=126, value=21644, is_min_estimate=False, callers={'RRF._answer_single_question': 126})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=127, value=21821, is_min_estimate=False, callers={'RRF._answer_single_question': 127})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=128, value=21976, is_min_estimate=False, callers={'RRF._answer_single_question': 128})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=129, value=22161, is_min_estimate=False, callers={'RRF._answer_single_question': 129})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=130, value=22335, is_min_estimate=False, callers={'RRF._answer_single_question': 130})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=131, value=22527, is_min_estimate=False, callers={'RRF._answer_single_question': 131})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=132, value=22715, is_min_estimate=False, callers={'RRF._answer_single_question': 132})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=133, value=22900, is_min_estimate=False, callers={'RRF._answer_single_question': 133})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '016', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=134, value=23087, is_min_estimate=False, callers={'RRF._answer_single_question': 134})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=135, value=23274, is_min_estimate=False, callers={'RRF._answer_single_question': 135})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=136, value=23439, is_min_estimate=False, callers={'RRF._answer_single_question': 136})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=137, value=23617, is_min_estimate=False, callers={'RRF._answer_single_question': 137})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=138, value=23784, is_min_estimate=False, callers={'RRF._answer_single_question': 138})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=139, value=23969, is_min_estimate=False, callers={'RRF._answer_single_question': 139})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=140, value=24150, is_min_estimate=False, callers={'RRF._answer_single_question': 140})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=141, value=24328, is_min_estimate=False, callers={'RRF._answer_single_question': 141})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=142, value=24508, is_min_estimate=False, callers={'RRF._answer_single_question': 142})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=143, value=24688, is_min_estimate=False, callers={'RRF._answer_single_question': 143})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=144, value=24846, is_min_estimate=False, callers={'RRF._answer_single_question': 144})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=145, value=25027, is_min_estimate=False, callers={'RRF._answer_single_question': 145})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=146, value=25197, is_min_estimate=False, callers={'RRF._answer_single_question': 146})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '018', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=147, value=25385, is_min_estimate=False, callers={'RRF._answer_single_question': 147})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=148, value=25569, is_min_estimate=False, callers={'RRF._answer_single_question': 148})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=149, value=25750, is_min_estimate=False, callers={'RRF._answer_single_question': 149})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=151, value=26116, is_min_estimate=False, callers={'RRF._answer_single_question': 151})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=151, value=26116, is_min_estimate=False, callers={'RRF._answer_single_question': 151})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=152, value=26277, is_min_estimate=False, callers={'RRF._answer_single_question': 152})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=154, value=26622, is_min_estimate=False, callers={'RRF._answer_single_question': 154})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=154, value=26622, is_min_estimate=False, callers={'RRF._answer_single_question': 154})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=155, value=26807, is_min_estimate=False, callers={'RRF._answer_single_question': 155})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=156, value=26988, is_min_estimate=False, callers={'RRF._answer_single_question': 156})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=157, value=27166, is_min_estimate=False, callers={'RRF._answer_single_question': 157})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=158, value=27346, is_min_estimate=False, callers={'RRF._answer_single_question': 158})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# ...
# (6, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=189, value=32658, is_min_estimate=False, callers={'RRF._answer_single_question': 189})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=190, value=32828, is_min_estimate=False, callers={'RRF._answer_single_question': 190})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '023', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=191, value=32996, is_min_estimate=False, callers={'RRF._answer_single_question': 191})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=192, value=33168, is_min_estimate=False, callers={'RRF._answer_single_question': 192})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=193, value=33316, is_min_estimate=False, callers={'RRF._answer_single_question': 193})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=194, value=33495, is_min_estimate=False, callers={'RRF._answer_single_question': 194})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=195, value=33656, is_min_estimate=False, callers={'RRF._answer_single_question': 195})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=196, value=33831, is_min_estimate=False, callers={'RRF._answer_single_question': 196})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=197, value=34005, is_min_estimate=False, callers={'RRF._answer_single_question': 197})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=198, value=34179, is_min_estimate=False, callers={'RRF._answer_single_question': 198})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=199, value=34351, is_min_estimate=False, callers={'RRF._answer_single_question': 199})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=200, value=34522, is_min_estimate=False, callers={'RRF._answer_single_question': 200})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=201, value=34674, is_min_estimate=False, callers={'RRF._answer_single_question': 201})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=202, value=34852, is_min_estimate=False, callers={'RRF._answer_single_question': 202})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=203, value=35012, is_min_estimate=False, callers={'RRF._answer_single_question': 203})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=204, value=35185, is_min_estimate=False, callers={'RRF._answer_single_question': 204})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=205, value=35359, is_min_estimate=False, callers={'RRF._answer_single_question': 205})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=206, value=35532, is_min_estimate=False, callers={'RRF._answer_single_question': 206})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=207, value=35703, is_min_estimate=False, callers={'RRF._answer_single_question': 207})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=208, value=35874, is_min_estimate=False, callers={'RRF._answer_single_question': 208})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=209, value=36025, is_min_estimate=False, callers={'RRF._answer_single_question': 209})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=210, value=36203, is_min_estimate=False, callers={'RRF._answer_single_question': 210})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=211, value=36363, is_min_estimate=False, callers={'RRF._answer_single_question': 211})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=212, value=36536, is_min_estimate=False, callers={'RRF._answer_single_question': 212})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=213, value=36710, is_min_estimate=False, callers={'RRF._answer_single_question': 213})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=214, value=36883, is_min_estimate=False, callers={'RRF._answer_single_question': 214})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=215, value=37054, is_min_estimate=False, callers={'RRF._answer_single_question': 215})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=216, value=37224, is_min_estimate=False, callers={'RRF._answer_single_question': 216})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=217, value=37375, is_min_estimate=False, callers={'RRF._answer_single_question': 217})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=218, value=37552, is_min_estimate=False, callers={'RRF._answer_single_question': 218})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=219, value=37711, is_min_estimate=False, callers={'RRF._answer_single_question': 219})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=220, value=37883, is_min_estimate=False, callers={'RRF._answer_single_question': 220})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=221, value=38056, is_min_estimate=False, callers={'RRF._answer_single_question': 221})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=222, value=38228, is_min_estimate=False, callers={'RRF._answer_single_question': 222})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=223, value=38398, is_min_estimate=False, callers={'RRF._answer_single_question': 223})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=224, value=38570, is_min_estimate=False, callers={'RRF._answer_single_question': 224})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=225, value=38720, is_min_estimate=False, callers={'RRF._answer_single_question': 225})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=226, value=38881, is_min_estimate=False, callers={'RRF._answer_single_question': 226})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=227, value=39060, is_min_estimate=False, callers={'RRF._answer_single_question': 227})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=228, value=39234, is_min_estimate=False, callers={'RRF._answer_single_question': 228})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=229, value=39409, is_min_estimate=False, callers={'RRF._answer_single_question': 229})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=230, value=39583, is_min_estimate=False, callers={'RRF._answer_single_question': 230})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=231, value=39755, is_min_estimate=False, callers={'RRF._answer_single_question': 231})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=232, value=39907, is_min_estimate=False, callers={'RRF._answer_single_question': 232})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (1, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=233, value=40078, is_min_estimate=False, callers={'RRF._answer_single_question': 233})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (2, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=234, value=40238, is_min_estimate=False, callers={'RRF._answer_single_question': 234})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (6, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=235, value=40411, is_min_estimate=False, callers={'RRF._answer_single_question': 235})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (0, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=236, value=40589, is_min_estimate=False, callers={'RRF._answer_single_question': 236})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (3, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=237, value=40763, is_min_estimate=False, callers={'RRF._answer_single_question': 237})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (5, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=238, value=40936, is_min_estimate=False, callers={'RRF._answer_single_question': 238})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (4, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=239, value=41107, is_min_estimate=False, callers={'RRF._answer_single_question': 239})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))
# (7, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=240, value=41258, is_min_estimate=False, callers={'RRF._answer_single_question': 240})}, _lock=<asyncio.locks.Lock object at 0x127690b90 [unlocked]>))

# %%
[s[:3] for s in [p for p in preds if p[0] == 1]]  # Preds for sample 1
# Out:
# [(1, '000', 'YES'),
#  (1, '001', 'NO'),
#  (1, '002', 'NO'),
#  (1, '003', 'NO'),
#  (1, '004', 'NO'),
#  (1, '005', 'NO'),
#  (1, '006', 'NO'),
#  (1, '007', 'YES'),
#  (1, '008', 'NO'),
#  (1, '009', 'NO'),
#  (1, '010', 'NO'),
#  (1, '011', 'NO'),
#  (1, '012', 'NO'),
#  (1, '013', 'NO'),
#  (1, '014', 'NO'),
#  (1, '015', 'YES'),
#  (1, '016', 'NO'),
#  (1, '017', 'NO'),
#  (1, '018', 'NO'),
#  (1, '019', 'NO'),
#  (1, '020', 'NO'),
#  (1, '021', 'NO'),
#  (1, '022', 'YES'),
#  (1, '023', 'NO'),
#  (1, '024', 'NO'),
#  (1, '025', 'NO'),
#  (1, '026', 'NO'),
#  (1, '027', 'NO'),
#  (1, '028', 'NO'),
#  (1, '029', 'NO')]

# %% [markdown]
# # Saving

# %%
rrf.save("example_rrf", for_production=True)

# %% [markdown]
# # Loading

# %%
loaded_rrf = RRF.load("example_rrf")

# %%
preds = []
async for pred in loaded_rrf.predict(X):
    preds.append(pred)  # type: ignore
    print(pred)
# Out:
# (0, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=1, value=181, is_min_estimate=False, callers={'RRF._answer_single_question': 1})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=2, value=344, is_min_estimate=False, callers={'RRF._answer_single_question': 2})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=3, value=518, is_min_estimate=False, callers={'RRF._answer_single_question': 3})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=4, value=692, is_min_estimate=False, callers={'RRF._answer_single_question': 4})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=5, value=869, is_min_estimate=False, callers={'RRF._answer_single_question': 5})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=6, value=1045, is_min_estimate=False, callers={'RRF._answer_single_question': 6})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '000', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=7, value=1199, is_min_estimate=False, callers={'RRF._answer_single_question': 7})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '000', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=8, value=1375, is_min_estimate=False, callers={'RRF._answer_single_question': 8})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=9, value=1558, is_min_estimate=False, callers={'RRF._answer_single_question': 9})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=10, value=1723, is_min_estimate=False, callers={'RRF._answer_single_question': 10})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=11, value=1899, is_min_estimate=False, callers={'RRF._answer_single_question': 11})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=12, value=2075, is_min_estimate=False, callers={'RRF._answer_single_question': 12})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=13, value=2254, is_min_estimate=False, callers={'RRF._answer_single_question': 13})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=14, value=2432, is_min_estimate=False, callers={'RRF._answer_single_question': 14})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '001', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=15, value=2588, is_min_estimate=False, callers={'RRF._answer_single_question': 15})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=16, value=2767, is_min_estimate=False, callers={'RRF._answer_single_question': 16})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '001', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=17, value=2945, is_min_estimate=False, callers={'RRF._answer_single_question': 17})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=18, value=3106, is_min_estimate=False, callers={'RRF._answer_single_question': 18})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=20, value=3450, is_min_estimate=False, callers={'RRF._answer_single_question': 20})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '002', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=20, value=3450, is_min_estimate=False, callers={'RRF._answer_single_question': 20})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=21, value=3625, is_min_estimate=False, callers={'RRF._answer_single_question': 21})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=22, value=3799, is_min_estimate=False, callers={'RRF._answer_single_question': 22})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=23, value=3951, is_min_estimate=False, callers={'RRF._answer_single_question': 23})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '003', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=24, value=4129, is_min_estimate=False, callers={'RRF._answer_single_question': 24})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '002', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=25, value=4303, is_min_estimate=False, callers={'RRF._answer_single_question': 25})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=26, value=4463, is_min_estimate=False, callers={'RRF._answer_single_question': 26})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=27, value=4634, is_min_estimate=False, callers={'RRF._answer_single_question': 27})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=28, value=4805, is_min_estimate=False, callers={'RRF._answer_single_question': 28})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=29, value=4979, is_min_estimate=False, callers={'RRF._answer_single_question': 29})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=30, value=5152, is_min_estimate=False, callers={'RRF._answer_single_question': 30})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=31, value=5303, is_min_estimate=False, callers={'RRF._answer_single_question': 31})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=32, value=5486, is_min_estimate=False, callers={'RRF._answer_single_question': 32})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '003', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=33, value=5659, is_min_estimate=False, callers={'RRF._answer_single_question': 33})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=34, value=5824, is_min_estimate=False, callers={'RRF._answer_single_question': 34})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=35, value=6000, is_min_estimate=False, callers={'RRF._answer_single_question': 35})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=36, value=6176, is_min_estimate=False, callers={'RRF._answer_single_question': 36})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=37, value=6355, is_min_estimate=False, callers={'RRF._answer_single_question': 37})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=38, value=6533, is_min_estimate=False, callers={'RRF._answer_single_question': 38})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=39, value=6689, is_min_estimate=False, callers={'RRF._answer_single_question': 39})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=40, value=6874, is_min_estimate=False, callers={'RRF._answer_single_question': 40})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '004', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=41, value=7052, is_min_estimate=False, callers={'RRF._answer_single_question': 41})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=42, value=7230, is_min_estimate=False, callers={'RRF._answer_single_question': 42})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=43, value=7397, is_min_estimate=False, callers={'RRF._answer_single_question': 43})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=44, value=7575, is_min_estimate=False, callers={'RRF._answer_single_question': 44})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=45, value=7755, is_min_estimate=False, callers={'RRF._answer_single_question': 45})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=46, value=7936, is_min_estimate=False, callers={'RRF._answer_single_question': 46})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=47, value=8094, is_min_estimate=False, callers={'RRF._answer_single_question': 47})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '005', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=49, value=8453, is_min_estimate=False, callers={'RRF._answer_single_question': 49})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=49, value=8453, is_min_estimate=False, callers={'RRF._answer_single_question': 49})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=50, value=8625, is_min_estimate=False, callers={'RRF._answer_single_question': 50})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=51, value=8797, is_min_estimate=False, callers={'RRF._answer_single_question': 51})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=52, value=8958, is_min_estimate=False, callers={'RRF._answer_single_question': 52})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=53, value=9132, is_min_estimate=False, callers={'RRF._answer_single_question': 53})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=54, value=9307, is_min_estimate=False, callers={'RRF._answer_single_question': 54})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '006', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=55, value=9459, is_min_estimate=False, callers={'RRF._answer_single_question': 55})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '006', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=56, value=9633, is_min_estimate=False, callers={'RRF._answer_single_question': 56})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '007', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=57, value=9814, is_min_estimate=False, callers={'RRF._answer_single_question': 57})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '007', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=58, value=9988, is_min_estimate=False, callers={'RRF._answer_single_question': 58})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=59, value=10162, is_min_estimate=False, callers={'RRF._answer_single_question': 59})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=60, value=10325, is_min_estimate=False, callers={'RRF._answer_single_question': 60})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=61, value=10501, is_min_estimate=False, callers={'RRF._answer_single_question': 61})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=62, value=10678, is_min_estimate=False, callers={'RRF._answer_single_question': 62})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '007', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=63, value=10832, is_min_estimate=False, callers={'RRF._answer_single_question': 63})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '007', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=64, value=11008, is_min_estimate=False, callers={'RRF._answer_single_question': 64})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '008', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=65, value=11198, is_min_estimate=False, callers={'RRF._answer_single_question': 65})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=66, value=11381, is_min_estimate=False, callers={'RRF._answer_single_question': 66})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=68, value=11736, is_min_estimate=False, callers={'RRF._answer_single_question': 68})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '008', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=68, value=11736, is_min_estimate=False, callers={'RRF._answer_single_question': 68})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=69, value=11921, is_min_estimate=False, callers={'RRF._answer_single_question': 69})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=70, value=12084, is_min_estimate=False, callers={'RRF._answer_single_question': 70})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '008', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=71, value=12270, is_min_estimate=False, callers={'RRF._answer_single_question': 71})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '008', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=72, value=12455, is_min_estimate=False, callers={'RRF._answer_single_question': 72})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=73, value=12631, is_min_estimate=False, callers={'RRF._answer_single_question': 73})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=74, value=12800, is_min_estimate=False, callers={'RRF._answer_single_question': 74})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=75, value=12969, is_min_estimate=False, callers={'RRF._answer_single_question': 75})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=76, value=13140, is_min_estimate=False, callers={'RRF._answer_single_question': 76})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=77, value=13298, is_min_estimate=False, callers={'RRF._answer_single_question': 77})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=78, value=13447, is_min_estimate=False, callers={'RRF._answer_single_question': 78})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=79, value=13619, is_min_estimate=False, callers={'RRF._answer_single_question': 79})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '009', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=80, value=13790, is_min_estimate=False, callers={'RRF._answer_single_question': 80})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=81, value=13969, is_min_estimate=False, callers={'RRF._answer_single_question': 81})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=82, value=14141, is_min_estimate=False, callers={'RRF._answer_single_question': 82})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=83, value=14313, is_min_estimate=False, callers={'RRF._answer_single_question': 83})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=84, value=14487, is_min_estimate=False, callers={'RRF._answer_single_question': 84})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=85, value=14639, is_min_estimate=False, callers={'RRF._answer_single_question': 85})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=86, value=14800, is_min_estimate=False, callers={'RRF._answer_single_question': 86})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=87, value=14975, is_min_estimate=False, callers={'RRF._answer_single_question': 87})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=88, value=15151, is_min_estimate=False, callers={'RRF._answer_single_question': 88})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '010', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=89, value=15325, is_min_estimate=False, callers={'RRF._answer_single_question': 89})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=90, value=15494, is_min_estimate=False, callers={'RRF._answer_single_question': 90})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=91, value=15665, is_min_estimate=False, callers={'RRF._answer_single_question': 91})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=92, value=15834, is_min_estimate=False, callers={'RRF._answer_single_question': 92})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=93, value=15983, is_min_estimate=False, callers={'RRF._answer_single_question': 93})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=94, value=16155, is_min_estimate=False, callers={'RRF._answer_single_question': 94})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=95, value=16313, is_min_estimate=False, callers={'RRF._answer_single_question': 95})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=96, value=16493, is_min_estimate=False, callers={'RRF._answer_single_question': 96})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=97, value=16666, is_min_estimate=False, callers={'RRF._answer_single_question': 97})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '011', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=98, value=16837, is_min_estimate=False, callers={'RRF._answer_single_question': 98})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=99, value=17012, is_min_estimate=False, callers={'RRF._answer_single_question': 99})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=100, value=17185, is_min_estimate=False, callers={'RRF._answer_single_question': 100})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=101, value=17338, is_min_estimate=False, callers={'RRF._answer_single_question': 101})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=102, value=17514, is_min_estimate=False, callers={'RRF._answer_single_question': 102})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=103, value=17695, is_min_estimate=False, callers={'RRF._answer_single_question': 103})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=104, value=17857, is_min_estimate=False, callers={'RRF._answer_single_question': 104})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=105, value=18031, is_min_estimate=False, callers={'RRF._answer_single_question': 105})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '012', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=106, value=18206, is_min_estimate=False, callers={'RRF._answer_single_question': 106})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=107, value=18382, is_min_estimate=False, callers={'RRF._answer_single_question': 107})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=108, value=18556, is_min_estimate=False, callers={'RRF._answer_single_question': 108})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=109, value=18710, is_min_estimate=False, callers={'RRF._answer_single_question': 109})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=110, value=18890, is_min_estimate=False, callers={'RRF._answer_single_question': 110})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=111, value=19067, is_min_estimate=False, callers={'RRF._answer_single_question': 111})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=112, value=19230, is_min_estimate=False, callers={'RRF._answer_single_question': 112})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '013', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=113, value=19406, is_min_estimate=False, callers={'RRF._answer_single_question': 113})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=114, value=19579, is_min_estimate=False, callers={'RRF._answer_single_question': 114})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=115, value=19754, is_min_estimate=False, callers={'RRF._answer_single_question': 115})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=116, value=19907, is_min_estimate=False, callers={'RRF._answer_single_question': 116})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=117, value=20080, is_min_estimate=False, callers={'RRF._answer_single_question': 117})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=118, value=20262, is_min_estimate=False, callers={'RRF._answer_single_question': 118})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=119, value=20438, is_min_estimate=False, callers={'RRF._answer_single_question': 119})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=120, value=20600, is_min_estimate=False, callers={'RRF._answer_single_question': 120})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '014', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=121, value=20775, is_min_estimate=False, callers={'RRF._answer_single_question': 121})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=122, value=20950, is_min_estimate=False, callers={'RRF._answer_single_question': 122})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=123, value=21127, is_min_estimate=False, callers={'RRF._answer_single_question': 123})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=124, value=21282, is_min_estimate=False, callers={'RRF._answer_single_question': 124})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=125, value=21457, is_min_estimate=False, callers={'RRF._answer_single_question': 125})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=126, value=21649, is_min_estimate=False, callers={'RRF._answer_single_question': 126})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=127, value=21827, is_min_estimate=False, callers={'RRF._answer_single_question': 127})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '015', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=128, value=21991, is_min_estimate=False, callers={'RRF._answer_single_question': 128})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '015', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=129, value=22168, is_min_estimate=False, callers={'RRF._answer_single_question': 129})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=130, value=22353, is_min_estimate=False, callers={'RRF._answer_single_question': 130})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=131, value=22540, is_min_estimate=False, callers={'RRF._answer_single_question': 131})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=132, value=22705, is_min_estimate=False, callers={'RRF._answer_single_question': 132})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=133, value=22890, is_min_estimate=False, callers={'RRF._answer_single_question': 133})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=134, value=23075, is_min_estimate=False, callers={'RRF._answer_single_question': 134})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=135, value=23263, is_min_estimate=False, callers={'RRF._answer_single_question': 135})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '016', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=136, value=23437, is_min_estimate=False, callers={'RRF._answer_single_question': 136})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '016', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=137, value=23624, is_min_estimate=False, callers={'RRF._answer_single_question': 137})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=138, value=23802, is_min_estimate=False, callers={'RRF._answer_single_question': 138})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=139, value=23982, is_min_estimate=False, callers={'RRF._answer_single_question': 139})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=140, value=24140, is_min_estimate=False, callers={'RRF._answer_single_question': 140})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=141, value=24318, is_min_estimate=False, callers={'RRF._answer_single_question': 141})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '018', 'YES', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=142, value=24506, is_min_estimate=False, callers={'RRF._answer_single_question': 142})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=143, value=24687, is_min_estimate=False, callers={'RRF._answer_single_question': 143})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=144, value=24854, is_min_estimate=False, callers={'RRF._answer_single_question': 144})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '017', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=145, value=25034, is_min_estimate=False, callers={'RRF._answer_single_question': 145})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=146, value=25215, is_min_estimate=False, callers={'RRF._answer_single_question': 146})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=147, value=25398, is_min_estimate=False, callers={'RRF._answer_single_question': 147})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=148, value=25559, is_min_estimate=False, callers={'RRF._answer_single_question': 148})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=149, value=25740, is_min_estimate=False, callers={'RRF._answer_single_question': 149})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=150, value=25925, is_min_estimate=False, callers={'RRF._answer_single_question': 150})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=151, value=26109, is_min_estimate=False, callers={'RRF._answer_single_question': 151})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=152, value=26279, is_min_estimate=False, callers={'RRF._answer_single_question': 152})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '018', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=153, value=26462, is_min_estimate=False, callers={'RRF._answer_single_question': 153})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=154, value=26640, is_min_estimate=False, callers={'RRF._answer_single_question': 154})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=155, value=26798, is_min_estimate=False, callers={'RRF._answer_single_question': 155})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=156, value=26978, is_min_estimate=False, callers={'RRF._answer_single_question': 156})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '019', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=157, value=27156, is_min_estimate=False, callers={'RRF._answer_single_question': 157})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '020', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=158, value=27338, is_min_estimate=False, callers={'RRF._answer_single_question': 158})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# ...
# (0, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=189, value=32657, is_min_estimate=False, callers={'RRF._answer_single_question': 189})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=190, value=32825, is_min_estimate=False, callers={'RRF._answer_single_question': 190})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=191, value=32995, is_min_estimate=False, callers={'RRF._answer_single_question': 191})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=192, value=33152, is_min_estimate=False, callers={'RRF._answer_single_question': 192})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '023', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=193, value=33323, is_min_estimate=False, callers={'RRF._answer_single_question': 193})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=194, value=33497, is_min_estimate=False, callers={'RRF._answer_single_question': 194})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=195, value=33649, is_min_estimate=False, callers={'RRF._answer_single_question': 195})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=196, value=33821, is_min_estimate=False, callers={'RRF._answer_single_question': 196})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=197, value=33999, is_min_estimate=False, callers={'RRF._answer_single_question': 197})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=198, value=34171, is_min_estimate=False, callers={'RRF._answer_single_question': 198})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=199, value=34345, is_min_estimate=False, callers={'RRF._answer_single_question': 199})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=200, value=34506, is_min_estimate=False, callers={'RRF._answer_single_question': 200})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '024', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=201, value=34681, is_min_estimate=False, callers={'RRF._answer_single_question': 201})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=202, value=34854, is_min_estimate=False, callers={'RRF._answer_single_question': 202})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=203, value=35005, is_min_estimate=False, callers={'RRF._answer_single_question': 203})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=204, value=35176, is_min_estimate=False, callers={'RRF._answer_single_question': 204})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=205, value=35354, is_min_estimate=False, callers={'RRF._answer_single_question': 205})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=206, value=35525, is_min_estimate=False, callers={'RRF._answer_single_question': 206})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=207, value=35698, is_min_estimate=False, callers={'RRF._answer_single_question': 207})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=208, value=35858, is_min_estimate=False, callers={'RRF._answer_single_question': 208})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=209, value=36031, is_min_estimate=False, callers={'RRF._answer_single_question': 209})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '025', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=210, value=36205, is_min_estimate=False, callers={'RRF._answer_single_question': 210})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=211, value=36356, is_min_estimate=False, callers={'RRF._answer_single_question': 211})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=212, value=36527, is_min_estimate=False, callers={'RRF._answer_single_question': 212})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=213, value=36704, is_min_estimate=False, callers={'RRF._answer_single_question': 213})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=214, value=36875, is_min_estimate=False, callers={'RRF._answer_single_question': 214})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=215, value=37048, is_min_estimate=False, callers={'RRF._answer_single_question': 215})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=216, value=37208, is_min_estimate=False, callers={'RRF._answer_single_question': 216})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=217, value=37380, is_min_estimate=False, callers={'RRF._answer_single_question': 217})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '026', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=218, value=37554, is_min_estimate=False, callers={'RRF._answer_single_question': 218})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=219, value=37704, is_min_estimate=False, callers={'RRF._answer_single_question': 219})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=220, value=37883, is_min_estimate=False, callers={'RRF._answer_single_question': 220})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=221, value=38053, is_min_estimate=False, callers={'RRF._answer_single_question': 221})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=222, value=38223, is_min_estimate=False, callers={'RRF._answer_single_question': 222})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=223, value=38382, is_min_estimate=False, callers={'RRF._answer_single_question': 223})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=224, value=38554, is_min_estimate=False, callers={'RRF._answer_single_question': 224})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=225, value=38728, is_min_estimate=False, callers={'RRF._answer_single_question': 225})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=226, value=38880, is_min_estimate=False, callers={'RRF._answer_single_question': 226})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '027', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=227, value=39053, is_min_estimate=False, callers={'RRF._answer_single_question': 227})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (0, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=228, value=39231, is_min_estimate=False, callers={'RRF._answer_single_question': 228})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=229, value=39403, is_min_estimate=False, callers={'RRF._answer_single_question': 229})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=230, value=39575, is_min_estimate=False, callers={'RRF._answer_single_question': 230})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=231, value=39736, is_min_estimate=False, callers={'RRF._answer_single_question': 231})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=232, value=39910, is_min_estimate=False, callers={'RRF._answer_single_question': 232})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (5, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=233, value=40083, is_min_estimate=False, callers={'RRF._answer_single_question': 233})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (7, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=234, value=40234, is_min_estimate=False, callers={'RRF._answer_single_question': 234})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (4, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=235, value=40405, is_min_estimate=False, callers={'RRF._answer_single_question': 235})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '028', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=236, value=40580, is_min_estimate=False, callers={'RRF._answer_single_question': 236})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (1, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=237, value=40751, is_min_estimate=False, callers={'RRF._answer_single_question': 237})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (6, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=238, value=40924, is_min_estimate=False, callers={'RRF._answer_single_question': 238})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (2, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=239, value=41084, is_min_estimate=False, callers={'RRF._answer_single_question': 239})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
# (3, '029', 'NO', TokenCounter(token_counts={'google/gemini-2.0-flash-lite': TokenCount(provider='google', model='gemini-2.0-flash-lite', number_of_calls=240, value=41258, is_min_estimate=False, callers={'RRF._answer_single_question': 240})}, _lock=<asyncio.locks.Lock object at 0x1273c6990 [unlocked]>))
